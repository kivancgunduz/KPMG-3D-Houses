# %% [markdown]
# Import Necessery Libraries

# %%
from osgeo import gdal
import numpy as np
from mpl_toolkits.mplot3d.axes3d import *
import matplotlib.pyplot as plt
from matplotlib import cm

# %% [markdown]
# Open TIFF File with GDAL

# %%
ds = gdal.Open("C:/Users/kivan/Desktop/becode_projects/KPMG-3D-Houses/DSM_files/DHMVIIDSMRAS1m_k01/GeoTIFF/DHMVIIDSMRAS1m_k01.tif")

ds_array = ds.GetRasterBand(1).ReadAsArray()

print(ds_array.shape)
# Out:
# (9000, 17000)

# %% [markdown]
# Rasterio

# %%
import rasterio
from rasterio.plot import show

fp = r'C:/Users/kivan/Desktop/becode_projects/KPMG-3D-Houses/DSM_files/DHMVIIDSMRAS1m_k01/GeoTIFF/DHMVIIDSMRAS1m_k01.tif'
img = rasterio.open(fp)

show(img)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Shape file with geopandas

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from pyarrow import feather

gdf = gpd.read_file('C:/Users/kivan/Desktop/becode_projects/KPMG-3D-Houses/DSM_files/DHMVIIDSMRAS1m_k01/DHMVII_vdc_k01/DHMVII_vdc_k01.shp')

gdf.plot(figsize=(5,5), edgecolor="purple", facecolor="None")
# Out:
# <AxesSubplot:>
